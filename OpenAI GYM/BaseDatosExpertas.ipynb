# %%
# !pip install stable_baselines3

# %%
#########################################################################
## MONTAR DRIVE
#########################################################################
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/pexpect/popen_spawn.py:60: DeprecationWarning: setDaemon() is deprecated, set the daemon attribute instead
#   self._read_thread.setDaemon(True)
# Mounted at /content/drive

# %%
import csv
from stable_baselines3 import PPO
import gymnasium as gym

# %%
TOTAL_TIMESTEP=25000
EPISODES_SECUENCIAS_EXPERTAS=9

# %% [markdown]
# # CartPole

# %%
expert_observations=[]
expert_actions=[]
expert_next_observations=[]
expert_rewards=[]


env = gym.make('CartPole-v1')

# Definimos el modelo experto
ppo=PPO(policy="MlpPolicy", env=env, verbose=0)
ppo.learn(total_timesteps=TOTAL_TIMESTEP)

expert_observations = '/content/drive/MyDrive/Extended_GAIL/observations_CartPole.csv'
expert_actions = '/content/drive/MyDrive/Extended_GAIL/actions_CartPole.csv'
expert_next_observations='/content/drive/MyDrive/Extended_GAIL/next_observations_CartPole.csv'
expert_rewards='/content/drive/MyDrive/Extended_GAIL/rewards_CartPole.csv'

with open(expert_observations, 'w', newline='') as expert_observations_csv:
    # Crear el escritor CSV
    escritor_csv_obs=csv.writer(expert_observations_csv)
    with open(expert_actions, 'w', newline='') as expert_actions_csv:
        escritor_csv_act=csv.writer(expert_actions_csv)
        with open(expert_next_observations, 'w', newline='') as expert_next_observations_csv:
            escritor_csv_next_obs=csv.writer(expert_next_observations_csv)
            with open(expert_rewards, 'w', newline='') as expert_rewards_csv:
                escritor_csv_reward=csv.writer(expert_rewards_csv)

                for i in range(EPISODES_SECUENCIAS_EXPERTAS):
                    obs, info = env.reset()
                    terminated = False
                    truncated=False
                    while not terminated and not truncated:
                        a, _ = ppo.predict(obs)
                        obs2, reward, terminated, truncated, info = env.step(a)

                        escritor_csv_obs.writerow(obs)

                        escritor_csv_act.writerow([a])
                        escritor_csv_next_obs.writerow(obs2)
                        escritor_csv_reward.writerow([reward])
                        obs=obs2

env.close()

# %% [markdown]
# # Lunar Lander

# %%
# !pip install swig
# Out:
# ...
#   Using cached swig-4.1.1.post0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
# ...

# %%
# !git clone https://github.com/pybox2d/pybox2d
# Out:
# Cloning into 'pybox2d'...
# remote: Enumerating objects: 3200, done.
# remote: Counting objects: 100% (343/343), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 3200 (delta 194), reused 325 (delta 187), pack-reused 2857
# Receiving objects: 100% (3200/3200), 9.26 MiB | 18.55 MiB/s, done.
# Resolving deltas: 100% (1988/1988), done.

# %%
# !cd pybox2d && python setup.py build && python setup.py install
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Box2D/Box2D_wrap.cpp: In function ‘PyObject* _wrap_new_b2Mat33(PyObject*, PyObject*)’:
# Box2D/Box2D_wrap.cpp:7349:3: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#  7349 |   if (!(argc = SWIG_Python_UnpackTuple(args, "new_b2Mat33", 0, 3, argv))) SWIG_fail; --argc; if (argc == 0) {
#       |   ^~
# Box2D/Box2D_wrap.cpp:7349:86: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#  7349 | (!(argc = SWIG_Python_UnpackTuple(args, "new_b2Mat33", 0, 3, argv))) SWIG_fail; --argc; if (argc == 0) {
#       |                                                                                 ^~
#
# Box2D/Box2D_wrap.cpp:7352:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#  7352 |     if (!SWIG_Python_TypeErrorOccurred(retobj)) return retobj; SWIG_fail;}  fail:
#       |     ^~
# ...

# %%
pip install gymnasium[box2d]
# Out:
# ...
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373077 sha256=801793ac81583abc692bf08808331a862df7b6c157d6b5968c542e0c1f534f7c
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# ...

# %%
expert_observations=[]
expert_actions=[]
expert_next_observations=[]
expert_rewards=[]


env = gym.make('LunarLander-v2')

# Definimos el modelo experto
ppo=PPO(policy="MlpPolicy", env=env, verbose=0)
ppo.learn(total_timesteps=TOTAL_TIMESTEP)

expert_observations = '/content/drive/MyDrive/Extended_GAIL/observations_LunarLander.csv'
expert_actions = '/content/drive/MyDrive/Extended_GAIL/actions_LunarLander.csv'
expert_next_observations='/content/drive/MyDrive/Extended_GAIL/next_observations_LunarLander.csv'
expert_rewards='/content/drive/MyDrive/Extended_GAIL/rewards_LunarLander.csv'

with open(expert_observations, 'w', newline='') as expert_observations_csv:
    # Crear el escritor CSV
    escritor_csv_obs=csv.writer(expert_observations_csv)
    with open(expert_actions, 'w', newline='') as expert_actions_csv:
        escritor_csv_act=csv.writer(expert_actions_csv)
        with open(expert_next_observations, 'w', newline='') as expert_next_observations_csv:
            escritor_csv_next_obs=csv.writer(expert_next_observations_csv)
            with open(expert_rewards, 'w', newline='') as expert_rewards_csv:
                escritor_csv_reward=csv.writer(expert_rewards_csv)

                for i in range(EPISODES_SECUENCIAS_EXPERTAS):
                    obs, info = env.reset()
                    terminated = False
                    truncated=False
                    while not terminated and not truncated:
                        a, _ = ppo.predict(obs)
                        obs2, reward, terminated, truncated, info = env.step(a)

                        escritor_csv_obs.writerow(obs)

                        escritor_csv_act.writerow([a])
                        escritor_csv_next_obs.writerow(obs2)
                        escritor_csv_reward.writerow([reward])
                        obs=obs2

env.close()

# %% [markdown]
# # Acrobot

# %%
expert_observations=[]
expert_actions=[]
expert_next_observations=[]
expert_rewards=[]


env = gym.make('Acrobot-v1')

# Definimos el modelo experto
ppo=PPO(policy="MlpPolicy", env=env, verbose=0)
ppo.learn(total_timesteps=TOTAL_TIMESTEP)

expert_observations = '/content/drive/MyDrive/Extended_GAIL/observations_Acrobot.csv'
expert_actions = '/content/drive/MyDrive/Extended_GAIL/actions_Acrobot.csv'
expert_next_observations='/content/drive/MyDrive/Extended_GAIL/next_observations_Acrobot.csv'
expert_rewards='/content/drive/MyDrive/Extended_GAIL/rewards_Acrobot.csv'

with open(expert_observations, 'w', newline='') as expert_observations_csv:
    # Crear el escritor CSV
    escritor_csv_obs=csv.writer(expert_observations_csv)
    with open(expert_actions, 'w', newline='') as expert_actions_csv:
        escritor_csv_act=csv.writer(expert_actions_csv)
        with open(expert_next_observations, 'w', newline='') as expert_next_observations_csv:
            escritor_csv_next_obs=csv.writer(expert_next_observations_csv)
            with open(expert_rewards, 'w', newline='') as expert_rewards_csv:
                escritor_csv_reward=csv.writer(expert_rewards_csv)

                for i in range(EPISODES_SECUENCIAS_EXPERTAS):
                    obs, info = env.reset()
                    terminated = False
                    truncated=False
                    while not terminated and not truncated:
                        a, _ = ppo.predict(obs)
                        obs2, reward, terminated, truncated, info = env.step(a)

                        escritor_csv_obs.writerow(obs)

                        escritor_csv_act.writerow([a])
                        escritor_csv_next_obs.writerow(obs2)
                        escritor_csv_reward.writerow([reward])
                        obs=obs2

env.close()
